# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c = 'YYNY'
n = len(c)
pre = [] * n + 1    # no of N before kth hour
suf = [] * n + 1    # no of Y after and including kth hour

pre[0] = 0
for i in range(0,n):
    Ncount = 0  
    if c[i] == 'N':
        Ncount += 1
        pre[i + 1] = pre[i] + Ncount

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr = [1,2,3,4,5,5,10,10]
n = len(arr)

# TODO: Formation of prefix sum
for i in range(n):
    arr[i] = arr[i] + arr[i - 1]


# Check if any x exists
# flag = False
idx = -1
for i in range(1,n):
    if 2 * arr[i] == arr[n-1]:
        flag = True
        idx = i
        break

if idx != -1:
    print(f"Can be partitioned after {idx}")
else:
    print(f"Cant Partitioned")
# Out:
# Can be partitioned after 4

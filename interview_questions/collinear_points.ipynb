# %%
def collinear_points(x1,x2,x3,y1,y2,y3):
    if ((y3-y2) * (x2-x1)) == ((y2-y1) * (x3-x2)):
        print("Yes")
    else:
        print('No')

# %%
x1,x2,x3,y1,y2,y3 = 1,1,1,6,0,9
collinear_points(x1,x2,x3,y1,y2,y3)
# Out:
# Yes

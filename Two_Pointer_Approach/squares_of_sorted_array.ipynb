# %%
# TODO: Trick
nums = [-4,-1,0,3,10]
print(sorted([x**2 for x in nums]))
# Out:
# [0, 1, 9, 16, 100]

# %%
# TODO: Two Pointer Approach
nums = [-4,-1,0,3,10]
result = [0] * len(nums)
left, right = 0, len(nums) - 1

for i in range(len(nums) - 1, -1, -1):
    if abs(nums[left]) > abs(nums[right]):
        result[i] = nums[left] ** 2
        left += 1
    else:
        result[i] = nums[right] ** 2
        right -= 1

# %%
nums = [-4,-1,0,3,10]
neg_array = []
pos_array = []
for num in nums:
    if num < 0:
        neg_array.append(num)
    else:
        pos_array.append(num)

# Merge two sorted array from two sorted arry
res = []

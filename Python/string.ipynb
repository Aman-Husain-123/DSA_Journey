# %%
print("Aman")
# Out:
# Aman

# %%
print('Aman')
# Out:
# Aman

# %%
print("Aman's Pen")
# Out:
# Aman's Pen

# %%
s = 'Aman'
print(s)
# Out:
# Aman

# %%
a = '''
Hey this is Aman.
I hope you'r well
'''

print(a)
# Out:
# Hey this is Aman.
# I hope you'r well

# %%
a = 'Aman Husain Is A Good Boy'
print(a[2])
# Out:
# a

# %%
a = 'Hey this is aman'
for i in a:
    print(i,end='')
# Out:
# Hey this is aman

# %%
a = 'Aman Husain'
len(a)
# Out:
# 11

# %%
txt = 'aman Husain'
print('Am' in txt)
# Out:
# False

# %%
a = 'Aman is a good boy'
if 'Aman' in a:
    print(True)
else:
    print(False)
# Out:
# True

# %%
a = 'Aman is a good boy'
print("Aman" not in a)
# Out:
# False

# %%
x = 'ThisguyAmanisagoodboy'
print(x[7:11])
# Out:
# Aman

# %%
x = 'Aman is a good boy'
print(x[:11])
# Out:
# Aman is a g

# %%
a = 'Aman husain'
print(a[5:])
# Out:
# husain

# %%
a = 'Aman Husain'
print(a[-1:-5])

# %%
a = 'aman'
a.upper()
# Out:
# 'AMAN'

# %%
a = 'AMAN'
a.lower()
# Out:
# 'aman'

# %%
a = ' Aman, Husain '
a.strip()
# Out:
# 'Aman, Husain'

# %%
a = 'Jman'
a.replace('J','A')
# Out:
# 'Aman'

# %%
a = 'Aman Husain'
a.split(' ')
# Out:
# ['Aman', 'Husain']

# %%
a = 'Aman'
b = ' Husain'
c = a + b
c
# Out:
# 'Aman Husain'

# %%
age = "36"
txt = "Aman is " + age + " years old"
txt
# Out:
# 'Aman is 36 years old'

# %%
age = 36
txt = f"He is {age} years old"
print(txt)
# Out:
# He is 36 years old

# %%
txt = f'{2 * 6}'
txt
# Out:
# '12'

# %%
txt = "Aman is a \"good\" boy"
txt
# Out:
# 'Aman is a "good" boy'

# %%
txt = 'aman'
txt.capitalize()
# Out:
# 'Aman'

# %%
a = 'AMAN'
a.casefold()
# Out:
# 'aman'

# %%
txt = "banana"
x = txt.center(20)
for i in txt:
    print(len(i))
# Out:
# 1
# 1
# 1
# 1
# 1
# 1

# %%
a = 'AmanA'
a.count('A')
# Out:
# 2

# %%
txt = "My name is Ståle"

print(txt.encode(encoding="ascii",errors="backslashreplace"))
print(txt.encode(encoding="ascii",errors="ignore"))
print(txt.encode(encoding="ascii",errors="namereplace"))
print(txt.encode(encoding="ascii",errors="replace"))
print(txt.encode(encoding="ascii",errors="xmlcharrefreplace"))
# Out:
# b'My name is St\\xe5le'
# b'My name is Stle'
# b'My name is St\\N{LATIN SMALL LETTER A WITH RING ABOVE}le'
# b'My name is St?le'
# b'My name is St&#229;le'

# %%
txtx = 'AmanA'
txtx.find('m')
# Out:
# 1

# %%
a = 'Aman'
for i in a:
    print(a.count(i))
# Out:
# 1
# 1
# 1
# 1

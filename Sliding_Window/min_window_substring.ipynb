# %%
s = "ADOBECODEBANC"
t = "ABC"
m = len(s)
n = len(t)
min_length = -1

for i in s:
    strr = ""

    for j in t:
        if t[j] == s[i]:
            strr += s[i]

    min_length = min(min_length,len(strr))
min_length
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       8 strr = ""
#      10 for j in t:
# ---> 11     if t[j] == s[i]:
#      12         strr += s[i]
#      14 min_length = min(min_length,len(strr))
#
# TypeError: string indices must be integers, not 'str'

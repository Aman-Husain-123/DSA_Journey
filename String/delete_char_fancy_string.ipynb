# %%
s = "leeetcodeee"
result = ""

for i in range(len(s)):
    # Check if result has at least 2 characters and new one would make 3 in a row
    if len(result) >= 2 and result[-1] == s[i] and result[-2] == s[i]:
        continue   # skip this character
    result += s[i]

print(result)
# Out:
# leetcodee

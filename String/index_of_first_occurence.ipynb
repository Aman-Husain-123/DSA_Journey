# %%
haystack = "sadbutssad" 
needle = "sad"

left = 0
right = 0
bool = False
index = -1
while right < len(needle):
    if haystack[left] == needle[right]:
        bool = True
        index = right

print(index)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 bool = False
#       7 index = -1
# ----> 8 while right < len(needle):
#       9     if haystack[left] == needle[right]:
#      10         bool = True
#
# KeyboardInterrupt:

# %%
# s = "Hey man how are you"
# s = "you are how man Hey"
s = "a good   example"

splitt = s.split(" ")

new_strr = " "
for i in range(len(splitt)-1,-1,-1):
    new_strr += splitt[i] + " "

new_strr.strip()
# Out:
# 'example   good a'

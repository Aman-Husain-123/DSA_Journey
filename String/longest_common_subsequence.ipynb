# %%
text1 = "ezupkr"
text2 = "ubmrapg" 

mapp = {}

for i in range(len(text1)):
    mapp[text1[i]] = mapp.get(text1[i],0)+1

count = 0
for i in range(len(text2)):
    if text2[i] in mapp:
        count += 1
print(count)
# Out:
# 3

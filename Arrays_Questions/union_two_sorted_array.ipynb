# %%
arr1 = [1,1,2,4,5,6]
arr2 = [2,4,5,1,3,6,7,8]
sett = set()

for i in range(len(arr1)):
    sett.add(arr1[i])

for j in range(len(arr2)):
    sett.add(arr2[i])

sett
# Out:
# {1, 2, 4, 5, 6}

# %%
# Optimal
arr1 = [1,1,2,4,5,6]
arr2 = [2,4,5,1,3,6,7,8]

n1 = len(arr1)
n2 = len(arr2)

i,j = 0,0

unionarr = []

while i < n1 and j < n2:
    if a[o]

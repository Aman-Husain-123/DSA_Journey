# %%
arr = [-2,1,-3,4,-1,2]
i = 0
best_ending = arr[0]
ans = arr[0]
n = len(arr)

for i in range(1,n):
    v1 = best_ending + arr[i]
    v2 = arr[i]
    best_ending = min(v1,v2)
    ans = max(best_ending,ans)

print(ans)
# Out:
# 1

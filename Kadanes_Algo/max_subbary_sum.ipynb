# %%
arr = [2,3,-2,4]
i = 0
best_ending = arr[0]
ans = arr[0]

for i in range(1,len(arr)):
    v1 = best_ending + arr[i]
    v2 = arr[i]
    best_ending = max(v1,v2)
    ans = max(best_ending,ans)
print(ans)
# Out:
# 7

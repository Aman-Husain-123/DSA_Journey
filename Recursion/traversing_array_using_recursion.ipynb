# %%
def display(arr,n,idx):
    if idx == n:
        return
    
    print(arr[idx],end =  " ")
    display(arr,n,idx + 1)

# %%
arr = [2,1,6,3,9,0,2,7]
n = len(arr)
display(arr,n,0)
# Out:
# 2 1 6 3 9 0 2 7

# %%
def hanoi(n_of_disk,s,h,d):
    if n_of_disk == 0:
        return
    hanoi(n_of_disk - 1,s,d,h)
    print(s," -> ",d)
    hanoi(n_of_disk - 1,h,s,d)

# %%
n = 4
hanoi(n,'A','B','C')
# Out:
# A  ->  B
# A  ->  C
# B  ->  C
# A  ->  B
# C  ->  A
# C  ->  B
# A  ->  B
# A  ->  C
# B  ->  C
# B  ->  A
# C  ->  A
# B  ->  C
# A  ->  B
# A  ->  C
# B  ->  C

# %%
def reverse(arr,index):
    if index == len(arr):
        return []
    
    reverse(arr,index + 1)
    print(arr[index])

# %%
# Example
arr = [1, 2, 3, 4]
reverse(arr, 0)
# Out:
# 4
# 3
# 2
# 1

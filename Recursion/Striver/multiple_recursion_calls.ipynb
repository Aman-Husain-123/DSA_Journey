# %%
def f(n):     # 2^n
    if n <= 1:
        return n
    
    last = f(n - 1)
    slast = f(n - 2)
    return last + slast

# %%
f(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f(4)
#
# NameError: name 'f' is not defined

# %%
arr = [9]
result = ""
for item in arr:
    result += str(item)

new_arr = int(result)
new_arr += 1

print(new_arr)

new_arr = str(new_arr)

new_digit = []

for i in new_arr:
    new_digit.append(int(i))

print(new_digit)
# Out:
# 10
# 10
# [1, 0]

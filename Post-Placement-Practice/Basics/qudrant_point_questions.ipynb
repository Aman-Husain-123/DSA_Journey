# %%
x = int(input("Enter x:"))
y = int(input("Enter y:"))

if x > 0 and y > 0:
    print("1st Qudrant")
elif x < 0 and y > 0:
    print("2nd Quadrant")
elif x < 0 and y < 0:
    print("3rd Quadrant")
else:
    print("4th Qudrant")
# Out:
# 2nd Quadrant

# %%
n = 5
for i in range(n):
    for j in range(n,i,-1):
        print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
n = 5
for i in range(n):
    for j in range(1,n+1-i):
        print(j,end="")
    print()
# Out:
# 12345
# 1234
# 123
# 12
# 1

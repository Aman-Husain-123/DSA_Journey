# %%
def search_element(arr,n):
    if n == 1:
        return arr[0]

    st = 0
    end = n-1

    while st <= end:
        mid = st + (end - st) // 2

        if mid == 0 and nums[0] != nums[1]:
            return nums[mid]
        if mid == n-1 and nums[n-1] != nums[n-2]:
            return nums[mid]
        
        if nums[mid-1] != nums[mid] and nums[mid] != nums[mid + 1]:
            return nums[mid]
        

        # 
        if mid % 2 == 0:
            if nums[mid-1] == nums[mid]:
                end = mid - 1 s
            else:
                st = mid + 1
        else:
            if nums[mid-1] == nums[mid]:
                st = mid + 1
            else:
                end = mid - 1
    return -1

# %%
nums = [1,1,2,2,3,3,4,4,8,8,9]
n = len(nums)
print(search_element(nums,n))
# Out:
# 9

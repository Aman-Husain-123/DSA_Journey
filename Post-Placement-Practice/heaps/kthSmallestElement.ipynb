# %%
import heapq
import heapq
arr = [10, 20, -4, 5, 18, 24, 1, -7, 56]
k = 4

max_heap = []

for num in arr:
    heapq.heappush(max_heap,-num)
    if len(max_heap) > k:
        heapq.heappop(max_heap)

print(-max_heap[0])
# Out:
# 5

# %%
import heapq
import heapq
arr = [10, 20, -4, 5, 18, 24, 1, -7, 56]
k = 4

max_heap = []

for num in arr:
    heapq.heappush(max_heap,num)
    if len(max_heap) > k:
        heapq.heappop(max_heap)

print(max_heap[0])
# Out:
# 18

# %%
# 1. Try to represent the problem in terms of index
# 2. Do all possible stuffs on that index according to the problem statement
# 3. Sum of all stufs if questions says count all ways
# if the que says find min then take min of all stuffs

# %%
# TODO: Memoization to DP
# 1. Declare base case 
# 2. Express all states in for loops
# 3. Copy the recurrence and write

# %%
# TODO: Converting into tabulation
# 1. Base case
# 2. Looks at the changing param and writes nested loops
# 3. Copy the recursion

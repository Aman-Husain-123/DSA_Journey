# %%
def pip(n):
    if n == 0:
        return 
    print("Pre ",n)
    pip(n-1)

    print("In ",n)
    pip(n-1)

    print("Post ",n)

pip(2)
# Out:
# Pre  2
# Pre  1
# In  1
# Post  1
# In  2
# Pre  1
# In  1
# Post  1
# Post  2

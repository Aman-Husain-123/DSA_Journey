# %%
class Solution:
    def f(self,n):
        if n == 2:
           return 3
          
        if n == 3:
            return 5
        
        return self.f(n-1) + self.f(n-2)
        
    def countStrings(self, n):
       # code here 
        return self.f(n)

n = 3
obj = Solution()
obj.f(n)
# Out:
# 5

# %%
arr = [1,2,3,3,2]
n = len(arr)

for i in range(n):
    for j in range(i,n):
        for k in range(i,j+1):
            print(arr[k], end=" ")
        print()
# Out:
# 1
# 1 2
# 1 2 3
# 1 2 3 3
# 1 2 3 3 2
# 2
# 2 3
# 2 3 3
# 2 3 3 2
# 3
# 3 3
# 3 3 2
# 3
# 3 2
# 2

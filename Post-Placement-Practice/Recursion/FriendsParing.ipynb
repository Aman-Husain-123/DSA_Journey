# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n == 1 or n == 2:
        retirn n
    
    return f(n-1) + (n-1) * f(n-2)

f(4)

# %%
            #              f(4)
            #         /             \
            #       f(3)          3 × f(2)
            #     /      \              |
            #   f(2)    2 × f(1)       f(2)
            #    |          |             |
            #    2          1             2

# %%
# CALL f(4)
#     |
#     |-- CALL f(3)
#     |      |
#     |      |-- CALL f(2)
#     |      |      |
#     |      |      └── return 2
#     |      |
#     |      |-- CALL f(1)
#     |      |      |
#     |      |      └── return 1
#     |      |
#     |      └── return 2 + 2×1 = 4
#     |
#     |-- CALL f(2)
#     |      |
#     |      └── return 2
#     |
#     └── return 4 + 3×2 = 10

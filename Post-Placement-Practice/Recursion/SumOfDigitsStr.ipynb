# %%
def sumofdigit(s,i):
    if i == len(s):
        return 0
    
    return (ord(s[i]) - ord('0')) + sumofdigit(s,i+1)

# %%
s = "12345"
print(sumofdigit(s, 0))
# Out:
# 15

# %%
# sum_digits("1234", 0)
# = 1 + sum_digits("1234", 1)
#       |
#       = 2 + sum_digits("1234", 2)
#             |
#             = 3 + sum_digits("1234", 3)
#                   |
#                   = 4 + sum_digits("1234", 4)
#                         |
#                         = 0   (Base Case)

# %%
# sum_digits("1234", 4)
# = 0

# sum_digits("1234", 3)
# = 4 + 0
# = 4

# sum_digits("1234", 2)
# = 3 + 4
# = 7

# sum_digits("1234", 1)
# = 2 + 7
# = 9

# sum_digits("1234", 0)
# = 1 + 9
# = 10

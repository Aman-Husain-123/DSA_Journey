# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(str,i,output):
    if i == len(str):
        print(output)
        return 
    
    f(str,i+1,output + str[i])
    f(str,i+1,output)

s="abc"
f(s,0,"")
# Out:
# abc
# ab
# ac
# a
# bc
# b
# c

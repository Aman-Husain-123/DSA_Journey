# %%
class TreeNode:
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

# %%
class MyBST:
    def __init__(self):
        self.root = None
    def construct_tree(self):
        self.root = TreeNode(40)
        self.root.left = TreeNode(30)
        self.root.right = TreeNode(50) 
        self.root.left.left = TreeNode(25)
        self.root.left.right = TreeNode(35)
        self.root.right.left = TreeNode(45)
        self.root.right.right = TreeNode(60)
    
    def inorder(self,root):
        if not True:
            return
        
        self.inorder(self.root.left)
        print(self.root.val,end = " ")
        self.inorder(self.root.right,val = " ")

# %%
My_BST = MyBST()
My_BST.construct_tree()

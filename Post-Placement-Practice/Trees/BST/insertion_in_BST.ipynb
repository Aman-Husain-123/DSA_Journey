# %%
## class of nodes in a BST
class Node:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

## insertion in BST
def insertBST(root, key):
    if root is None:
        return Node(key)
    else:
        if root.data == key:
            return root
        elif root.data < key:
            root.right = insertBST(root.right, key)
        else:
            root.left = insertBST(root.left, key)
    return root

## minimum value in BST
## def minValBST()

## inorder traversal of BST
def inOrder(root):
    if root:
        ## recursive call for left subtree
        inOrder(root.left)
        print(str(root.data)+" ", end=' ')
        ## recursive call for right subtree
        inOrder(root.right)
        
## Driver method
root = Node(100)
root = insertBST(root, 80)
root = insertBST(root, 110)
root = insertBST(root, 50)
root = insertBST(root, 90)

print("Inorder Traversal")
inOrder(root)
# Out:
# Inorder Traversal
# 50  80  90  100  110

# %%
def searchBST(root,searchData):
    # TODO: Base Case Condition
    if root is None or root.data == searchData:
        return root
    
    # TODO: Right recursive call
    if root.data < searchData:
        return searchData(root.right,searchData)
    
    # TODO: Left recursive call 
    return searchBST(root.left,searchData)

# %%
searchData = 60
if searchBST(root,searchData):
    print("Search data is present in BST")s
else:
    print("The searchded data is on present in BST")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 searchData = 60
# ----> 2 if searchBST(root,searchData):
#       3     print("Search data is present in BST")
#       4 else:
#
# Cell In[10], line 11, in searchBST(root, searchData)
#       8     return searchData(root.right,searchData)
#      10 # TODO: Left recursive call
# ---> 11 return searchBST(root.left,searchData)
#
# Cell In[10], line 11, in searchBST(root, searchData)
#       8     return searchData(root.right,searchData)
#      10 # TODO: Left recursive call
# ---> 11 return searchBST(root.left,searchData)
#
# Cell In[10], line 8, in searchBST(root, searchData)
#       6 # TODO: Right recursive call
#       7 if root.data < searchData:
# ----> 8     return searchData(root.right,searchData)
#      10 # TODO: Left recursive call
#      11 return searchBST(root.left,searchData)
#
# ...

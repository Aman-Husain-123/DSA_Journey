# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class TreeNode:
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

# %%
# TODO: Nodes
A = TreeNode("A")
B = TreeNode("B")
C = TreeNode("C")
D = TreeNode("D")
E = TreeNode("E")
F = TreeNode("F")

# %%
# TODO: Edges
A.left = B
A.right = C
B.left = D
B.right = E
C.left = F

# %%
prices = [7,1,5,3,6,4]
buy = prices[0]
profit = 0

for i in range(len(prices)):
    if prices[i] < buy:
        buy = prices[i]
    else:
        profit = max(profit,prices[i] - buy)

print(profit)
# Out:
# 5

# %%
nums = [4,1,2,1,2]
nums.sort()
print(nums)
i = 0

while i < len(nums) - 1:
    if nums[i] != nums[i + 1]:
        print(nums)
        i += 1
        break
# Out:
# [1, 1, 2, 2, 4]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 6
#       3 print(nums)
#       4 i = 0
# ----> 6 while i < len(nums) - 1:
#       7     if nums[i] != nums[i + 1]:
#       8         print(nums)
#
# KeyboardInterrupt:

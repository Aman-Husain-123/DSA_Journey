# %%
ransomNote = "aa"
magazine = "aab"
mpp1 = {}

for ch in magazine:
    if ch in mpp1:
        mpp1[ch] += 1
    else:
        mpp1[ch] = 1

mpp2 = {}
for ch in ransomNote:
    if ch in mpp2:
        mpp2[ch] += 1
    else:
        mpp2[ch] = 1

for key,value in mpp1.items():
    if key not in mpp2 or mpp2[key] > mpp1[key]:
        print(True)
    else:
        print(False)
# Out:
# False
# True

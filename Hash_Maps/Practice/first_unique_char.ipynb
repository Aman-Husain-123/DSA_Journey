# %%
s = "lleetcode"
mapp = {}
for ch in s:
    if ch in mapp:
        mapp[ch] += 1
    else:
        mapp[ch] = 1

for i,ch in enumerate(s):r
    if mapp[ch] == 1:
        print(i)
        break
print(mapp)
# Out:
# ...
# 4
# {'l': 2, 'e': 3, 't': 1, 'c': 1, 'o': 1, 'd': 1}

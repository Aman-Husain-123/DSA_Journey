# %%
ransomNote = "aa"
magazine = "bb"

mpp1 = {}
for c in magazine:
    mpp1[c] = mpp1.get(c,0) + 1

print("mpp1: ", mpp1)

mpp2 = {}
for c in ransomNote:
    mpp2[c] = mpp2.get(c,0) + 1

print("mpp2: ", mpp2)

for key,value in mpp2.items():
    # print(mpp1[key])
    # print(mpp2[key])
    if key not in mpp1 or mpp1[key] < mpp2[key]:
        print(False)
# print(True)
# Out:
# mpp1:  {'b': 2}
# mpp2:  {'a': 2}
# False

# %%
print(2//1)
# Out:
# 2

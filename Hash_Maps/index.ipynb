# %%
input_dict = {}
input_dict['name'] = 'Aman'

input_dict['Age'] = [1,2,3,4]
input_dict
# Out:
# {'name': 'Aman', 'Age': [1, 2, 3, 4]}

# %%
# Deleting Specific Key Value Pair
input_dict.pop('name')
# Out:
# 'Aman'

# %%
input_dict
# Out:
# {'Age': [1, 2, 3, 4]}

# %%
del input_dict['Age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 del input_dict['Age']
#
# KeyError: 'Age'

# %%
# Deleting Last Elemennt By Default
input_dict = {}
input_dict['name'] = 'Aman'

input_dict['Age'] = [1,2,3,4]
input_dict.popitem()
# Out:
# ('Age', [1, 2, 3, 4])

# %%
# Updaing Items
input_dict.update({'Age':[1,2,3,4,5]})

# %%
input_dict
# Out:
# {'name': 'Aman', 'Age': [1, 2, 3, 4, 5]}

# %%
# Clearing all the entries
input_dict.clear()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Clearing all the entries
# ----> 2 input_dict.clear()
#
# NameError: name 'input_dict' is not defined

# %%
input_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 input_dict
#
# NameError: name 'input_dict' is not defined

# %%
s = 'abca'
mpp = {}

for i in s:
    if i in mpp:
        mpp[i] += 1
    else:
        mpp[i] = 1

for key,val in enumerate(s):
    if mpp[val] == 1:
        print(key)
        break
# Out:
# 1

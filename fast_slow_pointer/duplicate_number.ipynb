# %%
n = [1,3,4,2,2]
for i in range(len(n)):
    for j in range(i+1, len(n)):
        if n[i] == n[j]:
            print(True)
            break
    else:
        continue
    break
else:
    print(False)
# Out:
# True

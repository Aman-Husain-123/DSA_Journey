# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

# %%
class LinkedList:
    def __init__(self):
        self.head = None
    def append(self, value):
        new_node = Node(value)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node
    def create_cycle(self, pos):
        if pos < 0:
            return
        cycle_start = None
        current = self.head
        for i in range(pos):
            if current is None:
                return
            current = current.next
        cycle_start = current
        while current and current.next:
            current = current.next
        if current:
            current.next = cycle_start
    def has_cycle(self):
        slow = self.head
        fast = self.head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            if slow == fast:
                return True
        return False
# Example usage:
linked_list = LinkedList()
linked_list.append(1)
linked_list.append(2)
linked_list.append(3)
linked_list.append(4)
linked_list.create_cycle(1)  # Creates a cycle starting at node with value 2
print(linked_list.has_cycle())  # Output: True
linked_list_no_cycle = LinkedList()
linked_list_no_cycle.append(1)
linked_list_no_cycle.append(2)
linked_list_no_cycle.append(3)
linked_list_no_cycle.append(4)
print(linked_list_no_cycle.has_cycle())  # Output: False
# Out:
# True
# False

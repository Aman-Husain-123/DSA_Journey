# %%
nums = [0,0,1,1,1,2,2,3,3,4]
i = 0
j = 1
no_of_unique = 1

while j < len(nums):
    if nums[j] == nums[j - 1]:s
        j += 1
    else:
        nums[i + 1] = nums[j]
        i += 1
        j += 1
        no_of_unique += 1
print(no_of_unique)
# Out:
# 5

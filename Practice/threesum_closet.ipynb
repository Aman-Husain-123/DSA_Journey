# %%
nums = [-1,2,1,-4]
target = 1

nums.sort()
n = len(nums)

closest_sum = nums[0] + nums[1] + nums[2]

for i in range(n):
    left = i  + 1
    right = n - 1

    while left < right:
        curr_sum = nums[i] + nums[left] + nums[right]

        if abs(curr_sum - target) < abs(closest_sum - target):
            closest_sum = curr_sum
        if curr_sum < target:s
            left += 1
        elif curr_sum > target:
            right -= 1
        else:
            break
print(closest_sum)
# Out:
# 2

# %%
def linear_search(arr,target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

# %%
arr = [21,212,4343,5,45]
target = 212
print(linear_search(arr,target))
# Out:
# 1

# %%
#  TODO: Binary Search

# %%
# Out:
# Element found at index: 2
